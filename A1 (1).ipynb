# %%
# Introduction to Python for Data Analytics

# Task 1: Print name and favorite app
print("Name: Shalu")
print("Favorite App: Instagram")


# Task 2: Print welcome message
print("Welcome to Data Analytics with Python!")


# Task 3: Print current year using datetime module
import datetime

current_year = datetime.datetime.now().year

print("Current Year:", current_year)
# Out:
# Name: Shalu
# Favorite App: Instagram
# Welcome to Data Analytics with Python!
# Current Year: 2026
