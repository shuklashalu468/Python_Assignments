# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration


song1 = Song("Kesariya", "Arijit Singh", 268)

print("Title:", song1.title)
print("Artist:", song1.artist)
print("Duration:", song1.duration, "seconds")
# Out:
# Title: Kesariya
# Artist: Arijit Singh
# Duration: 268 seconds

# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration


# Create an object
song1 = Song("Kesariya", "Arijit Singh", 268)

# Print title and artist
print("Title:", song1.title)
print("Artist:", song1.artist)
# Out:
# Title: Kesariya
# Artist: Arijit Singh

# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration

    def play_preview(self):
        print(f"Playing 30-second preview of {self.title} by {self.artist}")


# Create a Song object
song1 = Song("Kesariya", "Arijit Singh", 268)

# Call the method
song1.play_preview()
# Out:
# Playing 30-second preview of Kesariya by Arijit Singh

# %%
class FoodOrder:
    def __init__(self, restaurant_name):
        self.restaurant_name = restaurant_name
        self.items = []
        self.total_price = 0

    def add_item(self, item, price):
        self.items.append(item)
        self.total_price += price


# Create a FoodOrder object
order = FoodOrder("Domino's Pizza")

# Add two items
order.add_item("Margherita Pizza", 250)
order.add_item("Garlic Bread", 120)

# Display order details
print("Restaurant:", order.restaurant_name)
print("Items:", order.items)
print("Total Price: ₹", order.total_price)
# Out:
# Restaurant: Domino's Pizza
# Items: ['Margherita Pizza', 'Garlic Bread']
# Total Price: ₹ 370

# %%
class Song:
    def __init__(self, title, artist, duration):
        self.title = title
        self.artist = artist
        self.duration = duration
        self.play_count = 0

    def increment_play_count(self):
        self.play_count += 1


# Create a Song object
song1 = Song("Kesariya", "Arijit Singh", 268)

print("Initial play count:", song1.play_count)

# User plays the song 3 times
song1.increment_play_count()
song1.increment_play_count()
song1.increment_play_count()

print("Play count:", song1.play_count)
# Out:
# Initial play count: 0
# Play count: 3
