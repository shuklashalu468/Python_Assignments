# %%
movies = [
    "Kantara",
    "Dhurandhar",
    "War 2",
    "Saiyaara",
    "Chhaava"
]

# Create an iterator
movie_iterator = iter(movies)

# Get movies one by one
print(next(movie_iterator))
print(next(movie_iterator))
print(next(movie_iterator))
print(next(movie_iterator))
print(next(movie_iterator))
# Out:
# Kantara
# Dhurandhar
# War 2
# Saiyaara
# Chhaava

# %%
playlist = [
    "Kesariya",
    "Tum Hi Ho",
    "Apna Bana Le",
    "Chaleya",
    "Heeriye",
    "Tera Ban Jaunga"
]

for position, song in enumerate(playlist, start=1):
    print(f"{position}. {song}")
# Out:
# 1. Kesariya
# 2. Tum Hi Ho
# 3. Apna Bana Le
# 4. Chaleya
# 5. Heeriye
# 6. Tera Ban Jaunga

# %%
food_items = ["Pizza", "Burger", "Pasta", "Biryani", "Momos"]
prices = [250, 150, 200, 180, 120]

for food, price in zip(food_items, prices):
    print(f"{food} - ₹{price}")
# Out:
# Pizza - ₹250
# Burger - ₹150
# Pasta - ₹200
# Biryani - ₹180
# Momos - ₹120

# %%
def insta_posts_generator(posts):
    for post in posts:
        yield post


posts = [
    "Beautiful sunset 🌅",
    "Weekend vibes 😎",
    "Coffee time ☕",
    "Exploring new places 🌍",
    "Good memories ❤️"
]

post_generator = insta_posts_generator(posts)

while True:
    try:
        print(next(post_generator))
    except StopIteration:
        break
# Out:
# Beautiful sunset 🌅
# Weekend vibes 😎
# Coffee time ☕
# Exploring new places 🌍
# Good memories ❤️

# %%
def cashback_generator(transactions):
    for amount in transactions:
        cashback = amount * 0.05
        yield cashback


transactions = [100, 500, 1000, 250, 800]

cashback = cashback_generator(transactions)

for value in cashback:
    print("Cashback: ₹", value)
# Out:
# Cashback: ₹ 5.0
# Cashback: ₹ 25.0
# Cashback: ₹ 50.0
# Cashback: ₹ 12.5
# Cashback: ₹ 40.0

# %%
import math

number = 5

print("Square root:", math.sqrt(number))
print("Factorial:", math.factorial(number))
print("Value of pi:", math.pi)
# Out:
# Square root: 2.23606797749979
# Factorial: 120
# Value of pi: 3.141592653589793
