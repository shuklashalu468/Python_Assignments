# %%
import pandas as pd

# %%
# 1: create a Series named 'fav_cricket_teams'
fav_cricket_teams = pd.Series([
    "Chennai Super King",
    "Mumbai Indians",
    "Royal Challengers Bangalore",
    "Kolkata Knight Riders",
    "Rajasthan Royals"
])

# %%
# Print the Series.
fav_cricket_teams
# Out:
# 0             Chennai Super King
# 1                 Mumbai Indians
# 2    Royal Challengers Bangalore
# 3          Kolkata Knight Riders
# 4               Rajasthan Royals
# dtype: str

# %%
food_orders = pd.DataFrame({
    "Item": ["Pizza", "Maggie", "Burger"],
    "Restaurant": ["McDonalds", "Dominos", "Burger King"],
    "Price": [200, 50, 150]
})

# %%
food_orders
# Out:
#      Item   Restaurant  Price
# 0   Pizza    McDonalds    200
# 1  Maggie      Dominos     50
# 2  Burger  Burger King    150

# %%
# 3: create a pandas series called followers
followers = pd.Series([1200, 54000, 780, 150000, 32000])

# %%
followers
# Out:
# 0      1200
# 1     54000
# 2       780
# 3    150000
# 4     32000
# dtype: int64

# %%
followers.idxmax()
# Out:
# 3

# %%
followers.idxmin()
# Out:
# 2

# %%
followers.max()
# Out:
# np.int64(150000)

# %%
followers.min()
# Out:
# np.int64(780)

# %%
# 3:
playlist = pd.DataFrame({
    "Song" : ["Tose Naina", "Charka", "Parvati", "Bairan"],
    "Artist" : ["Arijit Singh", "Mukhtar Sahota", "Sadhu Tiwari", "Banjaree"],
    "Duration" : [4.2, 5.00, 3.25, 4.12]
})
print(playlist[["Song", "Duration"]])
# Out:
#          Song  Duration
# 0  Tose Naina      4.20
# 1      Charka      5.00
# 2     Parvati      3.25
# 3      Bairan      4.12
