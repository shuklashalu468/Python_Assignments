# %%
playlist_ids = [101, 205, 310, 415, 520]

# Add a new playlist ID
playlist_ids.append(625)

# Print the updated list
print("Updated Playlist IDs:", playlist_ids)
# Out:
# Updated Playlist IDs: [101, 205, 310, 415, 520, 625]

# %%
cart_items = ["t-shirt", "shoes"]

# Add more items to the cart
cart_items.extend(["jeans", "cap"])

# Print the final cart
print("Final Cart Items:", cart_items)
# Out:
# Final Cart Items: ['t-shirt', 'shoes', 'jeans', 'cap']

# %%
def remove_last_item(order_list):
    removed_item = order_list.pop()
    return removed_item

# Sample order list
order_list = ["Pizza", "Burger", "Cold Drink", "Ice Cream"]

print("Original Order List:", order_list)

removed = remove_last_item(order_list)

print("Removed Item:", removed)
print("Updated Order List:", order_list)
# Out:
# Original Order List: ['Pizza', 'Burger', 'Cold Drink', 'Ice Cream']
# Removed Item: Ice Cream
# Updated Order List: ['Pizza', 'Burger', 'Cold Drink']

# %%
# Create a tuple of Instagram filters
insta_filters = ("Clarendon", "Juno", "Lark", "Gingham")

print("Original Tuple:", insta_filters)

# Try to update the second filter
insta_filters[1] = "Valencia"

# This line will not execute because of the error above
print(insta_filters)

# Tuples are immutable, which means their elements cannot be
# be changed after the tuple is created.
# Out:
# Original Tuple: ('Clarendon', 'Juno', 'Lark', 'Gingham')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       3
#       4 print("Original Tuple:", insta_filters)
#       5
#       6 # Try to update the second filter
# ----> 7 insta_filters[1] = "Valencia"
#       8
#       9 # This line will not execute because of the error above
#      10 print(insta_filters)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Favorite genres can change, so use a list.
favorite_genres = ["Pop", "Rock", "Hip-Hop"]

# IRCTC train classes are fixed, so use a tuple.
train_classes = ("Sleeper", "AC 3 Tier", "AC 2 Tier")

print("Favorite Genres:", favorite_genres)
print("IRCTC Train Classes:", train_classes)
# Out:
# Favorite Genres: ['Pop', 'Rock', 'Hip-Hop']
# IRCTC Train Classes: ('Sleeper', 'AC 3 Tier', 'AC 2 Tier')
