# %%
# 1) Load the 'tips' dataset from seaborn and create a basic pairplot for all numerical columns.

import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

print(tips.head())

sns.pairplot(tips)

plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 2) Use the pairplot function to visualize the 'tips' dataset, but this time set the hue parameter to 'sex' and observe 
# how the data points are colored based on gender.

sns.pairplot(tips, hue="sex")

plt.show()

# %%
# 3) Create a pairplot for the 'tips' dataset with the hue set to 'smoker', and set the diag_kind parameter to 'kde' to show kernel 
# density estimates on the diagonal plots.<br><br><em><strong>Hint:</strong> Use diag_kind='kde' in the pairplot function.</em>

sns.pairplot(
    tips,
    hue="smoker",
    diag_kind="kde"
)

plt.show()

# %%
# 4) Pick any two numerical columns from the 'tips' dataset and use pairplot to visualize only those columns, setting hue to 'time' 
# (Lunch/Dinner).<br><br><em><strong>Constraint:</strong> Use the vars parameter to select the columns.</em>

sns.pairplot(
    tips,
    vars=["total_bill", "tip"],
    hue="time"
)

plt.show()
