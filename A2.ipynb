# %%
#1. Create three variables in Python: user_name, fav_app, and daily_usage_hours. Assign your own name, your favorite app (like Instagram or Zomato), and how many hours you use it daily.
 
user_name = "Shalu Shukla"
fav_app = "Instagram"
daily_usage_hours = 3

print("User Name :", user_name)
print("Favorite App :", fav_app)
print("Daily Usage Hours :", daily_usage_hours)
# Out:
# User Name : Shalu Shukla
# Favorite App : Instagram
# Daily Usage Hours : 3

# %%
user_name = "Shalu Shukla"
fav_app = "Zomato"
daily_usage_hours = 1

print("User Name :", user_name)
print("Favorite App :", fav_app)
print("Daily Usage Hours :", daily_usage_hours)
# Out:
# User Name : Shalu Shukla
# Favorite App : Zomato
# Daily Usage Hours : 1

# %%
#2. Write a Python script that declares variables for product_name, price, and is_available to represent an item on Flipkart. Print each variable and its data type using the type() function.

product_name = "Pen Drive"
price = 1499.98
is_available = True

print("Product name :", product_name)
print("Data type :", type(product_name))

print("Price :", price)
print("Data type :", type(price))

print("Is Available:", is_available)
print("Data type :", type(is_available))
# Out:
# Product name : Pen Drive
# Data type : <class 'str'>
# Price : 1499.98
# Data type : <class 'float'>
# Is Available: True
# Data type : <class 'bool'>

# %%
#Demonstrate the difference between single-line and multi-line comments in Python by writing a script that explains how a Spotify playlist recommendation system might work. Use # for single-line and triple quotes for multi-line comments.
# Spotify Playlist Recommendation System

# This program explains how spotify recommends playlists

"""
Spotify recommends playlist based on:
1. Your listening history.
2. Your favourite artists and songs.
3. Songs you like
4. Musics that users with similar tastes enjoy.
"""

print("Spotify Playlist Recommendation")
print("Recommended Playlist based on your preference ")
# Out:
# Spotify Playlist Recommendation
# Recommended Playlist based on your preference

# %%
#4. Create variables for order_total, delivery_region, and discount_percent to represent a Zomato order. Follow Python naming conventions and print a sentence using all three variables, like 'Order from [region] totals ₹[order_total] with [discount_percent]% discount.'

order_total = 950
delivery_region = "Dibrugarh"
discount_percent = 20

print(f"Order from {delivery_region} totals Rs{order_total} with {discount_percent}% discount.")
# Out:
# Order from Dibrugarh totals Rs950 with 20% discount.

# %%
# 5. Write a Python script that intentionally mixes tabs and spaces for indentation, then fix the script so it runs without errors.<br><br><em><strong>Hint:</strong> Use only spaces for indentation, as per Python's best practices.</em>

name = "Shalu"

if name == "Shalu":
    print("Hello")
    print("Welcome")
# Out:
# Hello
# Welcome
